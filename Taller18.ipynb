# %% [markdown]
# <a href="https://colab.research.google.com/github/juandi247/mc-2023-juan-diaz/blob/main/Taller18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

xn=np.array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5])

yn=np.array([4.2, 6.5, 7.5, 8, 8.5, 8.8, 9, 9.1])

n=len(xn)

Sum_x=sum(xn)
Sum_y=sum(yn)
Sum_xx=sum(xn**2)
Sum_xy=sum(xn*yn)

print(Sum_x, Sum_y, Sum_xx, Sum_xy)
# Out:
# 32.0 61.6 170.0 272.0

# %%
a_0=(Sum_xx*Sum_y-Sum_xy*Sum_x)/(n*Sum_xx-Sum_x**2)
a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
print(a_0, a_1)

x=np.linspace(0, 9)
y=a_0+a_1*x

plt.figure(1)

plt.scatter(xn, yn, color='r')
plt.grid(linestyle='dotted')
plt.plot(x, y, color='b')

plt.title(r'Regresión por Mínimos', fontsize=10)
plt.xlabel(r'x', fontsize=10)
plt.ylabel(r'y', fontsize=10)

plt.show()
# Out:
# 5.261904761904762 0.6095238095238094

# %%
import numpy as np
import matplotlib.pyplot as plt
xn=np.array([0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5])
yn=np.array([4.2,6.5,7.5,8,8.5,8.8,9,9.1])
ly=1/yn
lx=1/xn
n=len(xn)
Sum_x=sum(lx)
Sum_y=sum(ly)
Sum_xx=sum(lx**2)
Sum_xy=sum(lx*ly)


a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
a_0=(Sum_y/n)-(a_1*Sum_x/n)

print(a_1)
print(a_0)

α=1/a_0
β=a_1/a_0
print(α)
x=np.linspace(0,9)
y=α*(x/(β+x))
plt.figure(1)



plt.scatter(xn,yn,color='r')
plt.grid(linestyle='dotted')
plt.plot(x,y,color='b')

plt.title(r'Regresión por Mínimos',fontsize=10)
plt.xlabel(r'x',fontsize=10)
plt.ylabel(r'y',fontsize=10)

plt.show()
# Out:
# 0.06834990704206055
# 0.10327245337006552
# 9.683124273387886

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import e

xn=np.array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5])

yn=np.array([4.2, 6.5, 7.5, 8, 8.5, 8.8, 9, 9.1])

lny=np.log(yn)

print(lny)

n=len(xn)

Sum_x=sum(xn)
Sum_y=sum(lny)
Sum_xx=sum(xn**2)
Sum_xy=sum(xn*lny)

print(Sum_x, Sum_y, Sum_xx, Sum_xy)

a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
a_0= (Sum_y/n)-(a_1*Sum_x/n)

print(a_1)
print(a_0)

α=e**(a_0)
print(α)

x=np.linspace(0, 9)
y=α*np.e**(a_1*x)

plt.figure(1)

plt.scatter(xn, yn, color='r')
plt.grid(linestyle='dotted')
plt.plot(x, y, color='b')

plt.title(r'Regresión por Mínimos', fontsize=10)
plt.xlabel(r'x', fontsize=10)
plt.ylabel(r'y', fontsize=10)

plt.show()
# Out:
# [1.43508453 1.87180218 2.01490302 2.07944154 2.14006616 2.17475172
#  2.19722458 2.20827441]
# 32.0 16.121548140252468 170.0 68.2759985332347
# 0.09023347552916253
# 1.6542596154149085
# 5.229206864424189

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import e

xn=np.array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5])

yn=np.array([4.2, 6.5, 7.5, 8, 8.5, 8.8, 9, 9.1])

lny=np.log10(yn)
lnx=np.log10(xn)

print(lny)
print(lnx)

n=len(xn)

Sum_x=sum(lnx)
Sum_y=sum(lny)
Sum_xx=sum(lnx**2)
Sum_xy=sum(lnx*lny)

print(Sum_x,Sum_y,Sum_xx,Sum_xy)


a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
a_0=(Sum_y/n)-(a_1*Sum_x/n)

print(a_1)
print(a_0)

α=10**(a_0)
β=a_1

print(α)
print(a_1)

x=np.linspace(0,9)
y=α*(x**a_1)

plt.figure(1)

plt.scatter(xn,yn,color='r')
plt.grid(linestyle='dotted')
plt.plot(x,y,color='b')

plt.title(r'potencias',fontsize=10)
plt.xlabel(r'x',fontsize=10)
plt.ylabel(r'y',fontsize=10)

plt.show()
# Out:
# [0.62324929 0.81291336 0.87506126 0.90308999 0.92941893 0.94448267
#  0.95424251 0.95904139]
# [-0.30103     0.17609126  0.39794001  0.54406804  0.65321251  0.74036269
#   0.81291336  0.87506126]
# 3.8986191397181567 7.00149939704928 2.9773773174351934 3.7163987530851172
# 0.2824907821680556
# 0.7375219283618681
# 5.464141386838562
# 0.2824907821680556
